# %%
import pandas as pd
import glob
import re

# %%
csv_files = glob.glob('C:/Users/GB/Downloads/ten csv/*.csv')

data_frames = []

for file in csv_files:
    df = pd.read_csv(file)
    data_frames.append(df)
us_census = pd.concat(data_frames, ignore_index=True)

# %%
print(us_census.columns)
print(us_census.dtypes)
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'GenderPop'],
#       dtype='object')
# Unnamed: 0     int64
# State         object
# TotalPop       int64
# Hispanic      object
# White         object
# Black         object
# Native        object
# Asian         object
# Pacific       object
# Income        object
# GenderPop     object
# dtype: object

# %%
us_census['Income'] = us_census['Income'].replace('[\$,]', '', regex=True).astype(float)
us_census
# Out:
#     Unnamed: 0                 State  TotalPop             Hispanic  \
# 0            0               Alabama   4830620                3.75%
# 1            1                Alaska    733375                5.91%
# 2            2               Arizona   6641928               29.57%
# 3            3              Arkansas   2958208                6.22%
# 4            4            California  38421464               37.29%
# 5            5              Colorado   5278906               20.78%
# 6            0              Colorado   5278906   20.78438003220608%
# 7            1           Connecticut   3593222  15.604830917874388%
# 8            2              Delaware    926454    8.82476635514019%
# 9            3  District of Columbia    647484   9.165921787709499%
# 10           4               Florida  19645772    21.3385426653884%
# 11           5               Georgia  10006693   8.418242207460397%
# 12           0               Georgia  10006693   8.418242207460397%
# ...

# %%
us_census[['Men', 'Women']] = us_census['GenderPop'].str.split('_', expand=True)
us_census
# Out:
#     Unnamed: 0                 State  TotalPop             Hispanic  \
# 0            0               Alabama   4830620                3.75%
# 1            1                Alaska    733375                5.91%
# 2            2               Arizona   6641928               29.57%
# 3            3              Arkansas   2958208                6.22%
# 4            4            California  38421464               37.29%
# 5            5              Colorado   5278906               20.78%
# 6            0              Colorado   5278906   20.78438003220608%
# 7            1           Connecticut   3593222  15.604830917874388%
# 8            2              Delaware    926454    8.82476635514019%
# 9            3  District of Columbia    647484   9.165921787709499%
# 10           4               Florida  19645772    21.3385426653884%
# 11           5               Georgia  10006693   8.418242207460397%
# 12           0               Georgia  10006693   8.418242207460397%
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(us_census['Women'], us_census['Income'])
plt.xlabel('Proportion of Women')
plt.ylabel('Average Income')
plt.title('Scatterplot: Average Income vs Proportion of Women')
plt.show()

# %%
race_columns = ['Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific']
for column in race_columns:
    us_census[column] = us_census[column].replace('[\%]', '', regex=True).astype(float)
    us_census[column] = us_census[column].fillna(0)
    plt.hist(us_census[column])
    plt.xlabel('Percentage')
    plt.ylabel('Frequency')
    plt.title(f'Histogram: {column}')
    plt.show()
